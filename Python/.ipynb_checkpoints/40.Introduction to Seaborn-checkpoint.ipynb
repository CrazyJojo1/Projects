# %% [markdown]
# # Introduction to Seaborn (Very similar to ggplot package)
#
# ## Seaborn is a powerful visualisation package for python.
#
# - It builds on top of matplotlib. This means, Seaborn will make plot obained using matplotlib better. It does that by providing extra funcitons that are not available in matplotlib.
#     * This also means, you must have matplotlib imported in order to use Seaborn package.
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# #..................................other useful things
# #in order to print the plot in the same notebook we are working on
# %matplotlib inline
# #ignore warnings
# import warnings
# warnings.filterwarnings('ignore')
# #adjust the size of the plot
# plt.rcParams['figure.figsize'] = 8,4
# ```
# In order to get the better understanding of the types of plot you can get using Seaborn package. Click on the link below:
# [Seaborn Gallery](https://www.python-graph-gallery.com/seaborn/#google_vignette)
#
# **Tip on how to use this link:** Click on any chart. It will take you the web-page that will contain every detail on how to use it.
#
# ### Benefits:
# - It allows you to draw insights charts (Boxplot, scatterplot, density charts, histograms)
# - color and visuals are appealing as well.
#
# ## How to use seaborn
#
# **Histogram using $.distplot()$**
# ```python
# vis1 = sns.distplot(stats["InternetUsers"], bins=30)
# ```
#
# **Boxplot using $.boxplot( )$**
# ```python
# vis2 = sns.boxplot(data=stats, x="IncomeGroup",y="BirthRate")
# ```
# **Density distribution using $.kdeplot( )$**
# ```python
# plot2 = sns.kdeplot(stats["InternetUsers"])
# plot2.set_title('A distribution chart made with Seaborn')
# ```
#
# **Linear regression plot using $.lmplot( )$**
# ```python
# vis3 = sns.lmplot(data=stats, x="InternetUsers", y='BirthRate',fit_reg=False, hue="IncomeGroup",size=5,aspect = 3)
# #parameters used
# 1. fit_reg : removes the correlation line
# 2. hue : it is usd to add color to your plot (Using hue="columnname" is called mapping)
# 3. size : this parameter determines the size of your plot (lmplot size is 'not' controlled using plt.rcParams['figure,figsize']
# 4. aspect = width/height (aspect = 1 (meaning width of plot is equal to its height), aspect = 2 (width is twice the height)
# ```
# **other useful charts**
# ```
# 1. Barplot
# 2. boxplot
# 3. facetgrid
# 4. pairGrid
# 5. clustermap
#
# ```

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#in order to print the plot in the same notebook we are working on 
# %matplotlib inline

# %%
#Inorder to ignore warnings
import warnings
warnings.filterwarnings('ignore')

#Inorder to increase the width of the chart
plt.rcParams['figure.figsize']= 8,4

# %%
stats.head()
stats.describe()
stats[stats.InternetUsers <20]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 187           Vanuatu         VUT     26.739           11.3
# 189             Samoa         WSM     26.172           15.3
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 187  Lower middle income
# 189  Lower middle income
# ...

# %%
len(stats[(stats.InternetUsers <70) & (stats.InternetUsers > 20) & (stats.IncomeGroup =='High income')])
# Out:
# 25

# %%
#Let's create Distribution (using .distplot)

#just pass one column to distplot

vis1 = sns.distplot(stats.InternetUsers)

#other interesting plot in seaborn package
#Barplot
#boxplot
#facetgrid
#pairGrid
#clustermap

#Use .displot or .histplot instead of .distplot

# %%
#The bump in the graph (between 0 and 20) shows the more people falling in this group - mostly below upper middle income group

#between 20 and 70, you see a straight line (contains middle income and high income group)

#Density in the top internet Users list is very low

# %%
#Let's modify our plot

vis1 = sns.distplot(stats["InternetUsers"], bins=30)
                    
#press shift and tab to see the parameters for distplot function

# %%
#Boxplot

vis2 = sns.boxplot(data=stats, x="IncomeGroup",y="BirthRate")

# %%
#Seaborn gallery

# %%
#Revision


import pandas as pd
import os

#check the current directly
os.getcwd()

#importing the file
stats = pd.read_csv('demographic.csv')

stats

#checking the type
type(stats)

#exploring the data frame
stats.head(10)
stats.tail()

stats.columns #we will use this to change the column name

stats.info() #this is similar to str() function we use in R

stats.describe() #This is good when working with filtering as you know what the max, min, mean, median values 

#for more methods type dataframe. and tab

#stats.drop() this is used to drop the column

#changing column names

stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

stats.head() 

#why eliminating spaces in the names

#you can call the column easily then
stats.CountryName.head()

stats[['CountryName','CountryCode']][4:10]

stats[4:15]

#now adding column

stats['NJew'] = stats.BirthRate / stats.InternetUsers

stats

#eliminating extra column
stats.drop('NJew',axis=1,inplace=True) #inplace parameter will delete the column in the existing data frame so eliminates the need to overwrite

stats.head()

#checking categorical variables
stats.IncomeGroup.unique()

#filtering
stats[(stats.IncomeGroup == 'Upper middle income') &  (stats.BirthRate>20 )]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 2                Angola         AGO     45.985      19.100000
# 21               Belize         BLZ     23.092      33.600000
# 28             Botswana         BWA     25.267      15.000000
# 48   Dominican Republic         DOM     21.198      45.900000
# 49              Algeria         DZA     24.738      16.500000
# 50              Ecuador         ECU     21.070      40.353684
# ...
