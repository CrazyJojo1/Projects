# %% [markdown]
# # Manipulating datasets
#
# ## Things we will cover-
#
# | | |
# |---------------|-------------------|
# | 1. Getting our hands on the data | 5. Merging Data |
# | 2. Visualisation | 6. **Pivoting Data**  |
# | 3. Basic manipulations | 7. **Time series data**|
# |4. Data Grouping
#
# 1. Explore data sets both in numeric form and visually using plots.
#
# 2. Learn how to clean data sets (fix missing and wrong values)
#
# 3. Take different data sets and the combine them by merging, joining, and stacking.
#
# 4. Learn to transform different data sets into different format and pivot data sets. This will allow us to filter data to our need
#
# 5. Learn how to do vectorize operations
#
# 6. Manipulate and add features to our data so that it is ready for statistical analysis or for machine learning.
#
# 7. **Pivoting Data is advanced subject.**
#
# 8. Time series data is used almost in every analysis. e.g. Stock market, temp. history, etc.
#
# ------
#
# # What softwares to use-
#
# ## 1. Jupyter Notebook (- good for exploratory work - short projects or preliminary work)
#
# ### Jupyter labs
# - It comes with same functions as the jupyter notebook
#
# - **It is the file management stuff that is little different than jupyter notebook**; It is an imporvement upon jupyter notebooks.
#
# - It has better way of structuring your files and running them.
#
#
# ## 2. PyCharm (- recommended for large projects)
#
# **Use it when you need to integrate with Git and to work with huge code which require different files to interact with each other.**
#
# Git is used for creating your back-up creation and also, for downloading packages that add additional functionality to your IDE.
#
# - It is full fleged IDE.
#
# - But, for preliminary analysis jupyter notebook is a good choice.
#
# - It has all of that stuff built in.
#
# It has both free and paid version. Free version is all you need. Paid version has additional features that are used in web-server development.
#
# ----
#
# # Creating Backup file system
#
# If hardware (your computer or external hard-disk) has crashed, all your useful projects can become unretrievable. So it is very important to have a safe backup place.
#
# ## 1. Git
#
# 1. Use Git - put all your code on GitHub. Make it public.
#
# ## 2. PyCharm
#
# 2. Use PyCharm - Keeps track of your local file history
